# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.cluster import DBSCAN
from sklearn.datasets import make_moons
from sklearn.metrics import silhouette_score

# %%
x,y=make_moons(n_samples=250,noise=0.05)

# %%
df={"data1":x[:,0],"data2":x[:,1]}

# %%
dataset=pd.DataFrame(df)

# %%
dataset
# Out:
#         data1     data2
# 0    0.406434  0.940788
# 1    0.630862  0.918100
# 2   -0.376814  0.907470
# 3   -0.292684  0.950667
# 4    0.971684  0.105357
# ..        ...       ...
# 245  1.037875  0.144299
# 246  1.492462 -0.346239
# 247  1.000285 -0.429568
# 248  2.062295  0.581152
# 249 -1.004499  0.096951
#
# [250 rows x 2 columns]

# %%
dataset
sns.scatterplot(x="data1",y="data2",data=dataset)
plt.show()

# %%
db=DBSCAN(eps=0.3,min_samples=4)
dataset["pred"]=db.fit_predict(dataset)
sns.scatterplot(x="data1",y="data2",hue="pred",data=dataset)
# Out:
# <Axes: xlabel='data1', ylabel='data2'>

# %%
dataset['pred']
# Out:
# 0      0
# 1      0
# 2      0
# 3      0
# 4      0
#       ..
# 245    0
# 246    1
# 247    1
# 248    1
# 249    0
# Name: pred, Length: 250, dtype: int64
