# %%
# output data categorial hoga to ligistic regression apply hoga

# %%
import pandas as pd 
import numpy as np
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import LogisticRegression
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from mlxtend.plotting import plot_decision_regions
from sklearn.metrics import root_mean_squared_error,mean_absolute_error,mean_squared_error,r2_score
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt

# %%
data = pd.DataFrame({"Age":[20,23,35,26,19,30,33],"Selection":["n","n","y","y","n","y","y"]})

# %%
data
# Out:
#    Age Selection
# 0   20         n
# 1   23         n
# 2   35         y
# 3   26         y
# 4   19         n
# 5   30         y
# 6   33         y

# %%
lb = LabelEncoder()

# %%
data["Selection"] = lb.fit_transform(data[['Selection']])
# Out:
# C:\Users\sc024\anaconda3\Lib\site-packages\sklearn\preprocessing\_label.py:114: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)

# %%
data
# Out:
#    Age  Selection
# 0   20          0
# 1   23          0
# 2   35          1
# 3   26          1
# 4   19          0
# 5   30          1
# 6   33          1

# %%
plt.scatter(x,y, color ="r")

# %%
x= data[["Age"]]
y= data["Selection"]

# %%
xtrain,xtest,ytrain,ytest =train_test_split(x,y,test_size=0.2,random_state=3)

# %%
lr = LogisticRegression()

# %%
lr.fit(xtrain,ytrain)
# Out:
# LogisticRegression()

# %%
lr.predict([[35]])
# Out:
# C:\Users\sc024\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(
# array(['y'], dtype=object)

# %%
plot_decision_regions(x.to_numpy(),y.to_numpy(),clf = lr)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 plot_decision_regions(x.to_numpy(),y.to_numpy(),clf = lr)
#
# File ~\anaconda3\Lib\site-packages\mlxtend\plotting\decision_regions.py:161, in plot_decision_regions(X, y, clf, feature_index, filler_feature_values, filler_feature_ranges, ax, X_highlight, zoom_factor, legend, hide_spines, markers, colors, scatter_kwargs, contourf_kwargs, contour_kwargs, scatter_highlight_kwargs, n_jobs)
#      50 def plot_decision_regions(
#      51     X,
#      52     y,
#    (...)
#      72     n_jobs=None,
#      73 ):
#      74     """Plot decision regions of a classifier.
#      75
#      76     Please note that this functions assumes that class labels are
#    (...)
#     158
#     159     """
# --> 161     check_Xy(X, y, y_int=True)  # Validate X and y arrays
#     162     dim = X.shape[1]
# ...

# %%
# multiple column

# %%
data = pd.DataFrame({"Age":[20,23,35,26,19,30,33],"CGPA":[5,4,7,8,4,5,8],"Selection":["n","n","y","y","n","y","y"]})

# %%
data
# Out:
#    Age  CGPA Selection
# 0   20     5         n
# 1   23     4         n
# 2   35     7         y
# 3   26     8         y
# 4   19     4         n
# 5   30     5         y
# 6   33     8         y

# %%
lb = LabelEncoder()

# %%
data["Selection"] = lb.fit_transform(data[['Selection']])
# Out:
# C:\Users\sc024\anaconda3\Lib\site-packages\sklearn\preprocessing\_label.py:114: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)

# %%
data
# Out:
#    Age  CGPA  Selection
# 0   20     5          0
# 1   23     4          0
# 2   35     7          1
# 3   26     8          1
# 4   19     4          0
# 5   30     5          1
# 6   33     8          1

# %%
x= data[["Age","CGPA"]]
y= data["Selection"]

# %%
xtrain,xtest,ytrain,ytest =train_test_split(x,y,test_size=0.2,random_state=3)

# %%
lr = LogisticRegression()

# %%
lr.fit(xtrain,ytrain)
# Out:
# LogisticRegression()

# %%
lr.predict([[35,4]])
# Out:
# C:\Users\sc024\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(
# array([1])
